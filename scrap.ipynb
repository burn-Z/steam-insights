# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dir= 'data/'
file_names = ['categories.zip', 'descriptions.zip','games.zip','genres.zip','promotional.zip','reviews.zip','steamspy_insights.zip','tags.zip']

for fn in file_names:
    try:
        temp_df = pd.read_csv(dir + fn)
        print(f"Successfully read {fn} with shape {temp_df.shape}")
    except Exception as e:
        print(f"Failed to read {fn}: {e}")
        continue
# Out:
# Successfully read categories.zip with shape (522582, 2)
# Failed to read descriptions.zip: Error tokenizing data. C error: Expected 4 fields in line 12, saw 26
#
# Failed to read games.zip: Error tokenizing data. C error: Expected 13 fields in line 43, saw 14
#
# Successfully read genres.zip with shape (353339, 2)
# Failed to read promotional.zip: Error tokenizing data. C error: Expected 43 fields in line 12, saw 46
#
# Failed to read reviews.zip: Error tokenizing data. C error: Expected 13 fields in line 50, saw 14
#
# Failed to read steamspy_insights.zip: Error tokenizing data. C error: Expected 14 fields in line 7794, saw 15
#
# Successfully read tags.zip with shape (1744632, 2)

# %%
df.head()
# Out:
#    app_id                 category
# 0      10           Family Sharing
# 1      10             Multi-player
# 2      10               Online PvP
# 3      10                      PvP
# 4      10  Shared/Split Screen PvP
